# %%
import numpy as np
from scipy import stats

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 6])

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Define myfunc function
def myfunc(val):
    return slope * val + intercept

# Use list and map to apply myfunc over x
y_mapped = list(map(myfunc, x))

# Print results
glucose = myfunc(8)
print('Glucose: ', glucose)
# Out:
# Glucose:  8.2

# %%
import matplotlib.pyplot as plt

# Plot the data points
plt.scatter(x, y, label='Actual data', color='blue', s=100)

# Plot the regression line
y_line = slope * x + intercept
plt.plot(x, y_line, label='Regression line', color='red', linewidth=2)

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1, 2, 3, 5, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 18, 19]
y=[100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99]
plt.scatter(x, y)
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))
myline = np.linspace(1, 22, 100)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
